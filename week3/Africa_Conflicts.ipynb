# %%
import pandas as pd
import numpy as np
data = pd.read_csv(r"C:\Users\User\Desktop\Africa Conflicts.csv", sep=";")
df = pd.DataFrame(data)
df.head(10)
# Out:
#    ISO EVENT_ID_CNTY  EVENT_ID_NO_CNTY       EVENT_DATE  YEAR  TIME_PRECISION  \
# 0   12          ALG1                 1  01-janvier-1997  1997               1
# 1   12          ALG2                 2  02-janvier-1997  1997               1
# 2   12          ALG3                 3  03-janvier-1997  1997               1
# 3   12          ALG4                 4  04-janvier-1997  1997               1
# 4   12          ALG5                 5  05-janvier-1997  1997               1
# 5   12          ALG6                 6  06-janvier-1997  1997               1
# 6   12          ALG7                 7  06-janvier-1997  1997               1
# 7   12          ALG8                 8  07-janvier-1997  1997               1
# 8   12         ALG11                11  07-janvier-1997  1997               1
# 9   12          ALG9                 9  07-janvier-1997  1997               1
#
#                    EVENT_TYPE                 SUB_EVENT_TYPE  \
# 0  Violence against civilians                         Attack
# 1  Violence against civilians                         Attack
# 2  Violence against civilians                         Attack
# 3  Violence against civilians                         Attack
# 4  Violence against civilians                         Attack
# 5                     Battles                    Armed clash
# 6  Violence against civilians                         Attack
# 7  Explosions/Remote violence  Remote explosive/landmine/IED
# 8  Violence against civilians                         Attack
# 9  Explosions/Remote violence  Remote explosive/landmine/IED
#
#                                  ACTOR1 ASSOC_ACTOR_1  ...  ADMIN3  \
# 0              GIA: Armed Islamic Group           NaN  ...     NaN
# 1              GIA: Armed Islamic Group           NaN  ...     NaN
# 2              GIA: Armed Islamic Group           NaN  ...     NaN
# 3              GIA: Armed Islamic Group           NaN  ...     NaN
# 4              GIA: Armed Islamic Group           NaN  ...     NaN
# 5  Police Forces of Algeria (1994-1999)           NaN  ...     NaN
# 6              GIA: Armed Islamic Group           NaN  ...     NaN
# 7              GIA: Armed Islamic Group           NaN  ...     NaN
# 8              GIA: Armed Islamic Group           NaN  ...     NaN
# 9              GIA: Armed Islamic Group           NaN  ...     NaN
#
#         LOCATION LATITUDE  LONGITUDE  GEO_PRECISION         SOURCE  \
# 0       Douaouda    36672       2789              1  Algeria Watch
# 1       Hassasna    36133        883              1  Algeria Watch
# 2  Hassi El Abed    34966      -0,29              1  Algeria Watch
# 3          Blida    36469       2829              1  Algeria Watch
# 4       Douaouda    36672       2789              1  Algeria Watch
# 5     Ain Benian    36803       2922              1  Algeria Watch
# 6        Hadjout    36514       2418              1  Algeria Watch
# 7    Ain Fakroun    35971       6874              1  Algeria Watch
# 8          Jijel     36,8       5767              1  Algeria Watch
# 9        Algiers    36752       3042              1  Algeria Watch
#
#   SOURCE_SCALE                                              NOTES FATALITIES  \
# 0        Other  5 January: Beheading of 5 citizens in Douaouda...          5
# 1        Other            Two citizens were beheaded in Hassasna.          2
# 2        Other  Two citizens were killed in a raid on the vill...          2
# 3        Other  4 January: 16 citizens were murdered in the vi...         16
# 4        Other  5 January: Killing of 18 citizens in the Olivi...         18
# 5        Other  4 armed men were killed by security forces in ...          4
# 6        Other  6 January: 23 citizens were horribly mutilated...         23
# 7        Other  Explosion of a bomb in Ain Fakroun (Oum Bouagh...          7
# 8        Other  The president of the chamber of bailiffs of th...          1
# 9        Other  7 January: Explosion of a bomb in the Didouche...         20
#
#     TIMESTAMP
# 0  1582579226
# 1  1582579226
# 2  1582579226
# 3  1582579226
# 4  1582579226
# 5  1582579226
# 6  1600121120
# 7  1582579226
# 8  1582579226
# 9  1582579226
#
# [10 rows x 29 columns]

# %%
df.shape
# Out:
# (65535, 29)

# %%
df.info
# Out:
# <bound method DataFrame.info of        ISO EVENT_ID_CNTY  EVENT_ID_NO_CNTY        EVENT_DATE  YEAR  \
# 0       12          ALG1                 1   01-janvier-1997  1997
# 1       12          ALG2                 2   02-janvier-1997  1997
# 2       12          ALG3                 3   03-janvier-1997  1997
# 3       12          ALG4                 4   04-janvier-1997  1997
# 4       12          ALG5                 5   05-janvier-1997  1997
# ...    ...           ...               ...               ...   ...
# 65530  404        KEN318               318   25-octobre-1998  1998
# 65531  404        KEN319               319  02-novembre-1998  1998
# 65532  404        KEN320               320  10-novembre-1998  1998
# 65533  404        KEN323               323  14-novembre-1998  1998
# 65534  404        KEN322               322  14-novembre-1998  1998
#
#        TIME_PRECISION                  EVENT_TYPE    SUB_EVENT_TYPE  \
# 0                   1  Violence against civilians            Attack
# 1                   1  Violence against civilians            Attack
# 2                   1  Violence against civilians            Attack
# 3                   1  Violence against civilians            Attack
# 4                   1  Violence against civilians            Attack
# ...               ...                         ...               ...
# 65530               1  Violence against civilians            Attack
# 65531               1                    Protests  Peaceful protest
# 65532               1                     Battles       Armed clash
# 65533               1                     Battles       Armed clash
# 65534               1                     Battles       Armed clash
#
#                                                 ACTOR1  \
# 0                             GIA: Armed Islamic Group
# 1                             GIA: Armed Islamic Group
# 2                             GIA: Armed Islamic Group
# 3                             GIA: Armed Islamic Group
# 4                             GIA: Armed Islamic Group
# ...                                                ...
# 65530                      OLF: Oromo Liberation Front
# 65531                               Protesters (Kenya)
# 65532  SPLM/A: Sudan People's Liberation Movement/Army
# 65533  SPLM/A: Sudan People's Liberation Movement/Army
# 65534  SPLM/A: Sudan People's Liberation Movement/Army
#
#                        ASSOC_ACTOR_1  ...           ADMIN3       LOCATION  \
# 0                                NaN  ...              NaN       Douaouda
# 1                                NaN  ...              NaN       Hassasna
# 2                                NaN  ...              NaN  Hassi El Abed
# 3                                NaN  ...              NaN          Blida
# 4                                NaN  ...              NaN       Douaouda
# ...                              ...  ...              ...            ...
# 65530  Borana Ethnic Militia (Kenya)  ...         Township           Tuli
# 65531               Students (Kenya)  ...  Nairobi Central        Nairobi
# 65532                            NaN  ...  Nairobi Central        Nairobi
# 65533                            NaN  ...  Nairobi Central        Nairobi
# 65534                            NaN  ...  Nairobi Central        Nairobi
#
#       LATITUDE  LONGITUDE  GEO_PRECISION         SOURCE SOURCE_SCALE  \
# 0        36672       2789              1  Algeria Watch        Other
# 1        36133        883              1  Algeria Watch        Other
# 2        34966      -0,29              1  Algeria Watch        Other
# 3        36469       2829              1  Algeria Watch        Other
# 4        36672       2789              1  Algeria Watch        Other
# ...        ...        ...            ...            ...          ...
# 65530     1643      40343              1     All Africa     Regional
# 65531    -1283      36817              1     All Africa     Regional
# 65532    -1283      36817              1     All Africa     Regional
# 65533    -1283      36817              1     All Africa     Regional
# 65534    -1283      36817              1     All Africa     Regional
#
#                                                    NOTES FATALITIES  \
# 0      5 January: Beheading of 5 citizens in Douaouda...          5
# 1                Two citizens were beheaded in Hassasna.          2
# 2      Two citizens were killed in a raid on the vill...          2
# 3      4 January: 16 citizens were murdered in the vi...         16
# 4      5 January: Killing of 18 citizens in the Olivi...         18
# ...                                                  ...        ...
# 65530  OLF and Borana ethnic militia attack civilians...         28
# 65531  University students protest over killing in Wa...          0
# 65532  Garangs SPLA security men raid home of Kerubin...          0
# 65533       Rival SPLA factions battle at police station          0
# 65534  Gang of youth loyal to Kerubinos SPLA faction ...          0
#
#         TIMESTAMP
# 0      1582579226
# 1      1582579226
# 2      1582579226
# 3      1582579226
# 4      1582579226
# ...           ...
# 65530  1553544833
# 65531  1567465412
# 65532  1604344065
# 65533  1583194169
# 65534  1583194169
#
# [65535 rows x 29 columns]>

# %%
df.isnull().sum()
# Out:
# ISO                     0
# EVENT_ID_CNTY           0
# EVENT_ID_NO_CNTY        0
# EVENT_DATE              0
# YEAR                    0
# TIME_PRECISION          0
# EVENT_TYPE              0
# SUB_EVENT_TYPE          0
# ACTOR1                  0
# ASSOC_ACTOR_1       52767
# INTER1                  0
# ACTOR2              15189
# ASSOC_ACTOR_2       54368
# INTER2                  0
# INTERACTION             0
# REGION                  0
# COUNTRY                 0
# ADMIN1                  0
# ADMIN2                  0
# ADMIN3              13204
# LOCATION                0
# LATITUDE                0
# LONGITUDE               0
# GEO_PRECISION           0
# SOURCE                  0
# SOURCE_SCALE            0
# NOTES                2604
# FATALITIES              0
# TIMESTAMP               0
# dtype: int64

# %%
#dropping null values
df.dropna(inplace = True)
df
# Out:
#        ISO EVENT_ID_CNTY  EVENT_ID_NO_CNTY       EVENT_DATE  YEAR  \
# 12854   24       ANG2923              2923  15-juillet-2009  2009
# 12898   24       ANG2969              2969  28-juillet-2012  2012
# 12909   24       ANG2983              2983     15-juin-2013  2013
# 13020   24       ANG3096              3096      03-mai-2017  2017
# 13027   24       ANG3105              3105      17-mai-2017  2017
# ...    ...           ...               ...              ...   ...
# 65526  404        KEN315               315  25-octobre-1998  1998
# 65527  404        KEN316               316  25-octobre-1998  1998
# 65528  404        KEN317               317  25-octobre-1998  1998
# 65529  404        KEN313               313  25-octobre-1998  1998
# 65530  404        KEN318               318  25-octobre-1998  1998
#
#        TIME_PRECISION                  EVENT_TYPE  \
# 12854               3  Violence against civilians
# 12898               1                       Riots
# 12909               1                    Protests
# 13020               1                    Protests
# 13027               1                       Riots
# ...               ...                         ...
# 65526               1  Violence against civilians
# 65527               1  Violence against civilians
# 65528               1  Violence against civilians
# 65529               1  Violence against civilians
# 65530               1  Violence against civilians
#
#                            SUB_EVENT_TYPE                            ACTOR1  \
# 12854                     Sexual violence   Police Forces of Angola (1975-)
# 12898               Violent demonstration                  Rioters (Angola)
# 12909           Protest with intervention               Protesters (Angola)
# 13020  Excessive force against protesters               Protesters (Angola)
# 13027                        Mob violence                  Rioters (Angola)
# ...                                   ...                               ...
# 65526                              Attack       OLF: Oromo Liberation Front
# 65527                              Attack       OLF: Oromo Liberation Front
# 65528                              Attack       OLF: Oromo Liberation Front
# 65529                              Attack  Borana Ethnic Militia (Ethiopia)
# 65530                              Attack       OLF: Oromo Liberation Front
#
#                                            ASSOC_ACTOR_1  ...  \
# 12854  Military Forces of Angola (1975-); Civilians (...  ...
# 12898  UNITA: National Union for the Total Independen...  ...
# 12909                                     Women (Angola)  ...
# 13020                                 Prisoners (Angola)  ...
# 13027  MPLA: Popular Movement for the Liberation of A...  ...
# ...                                                  ...  ...
# 65526                      Borana Ethnic Militia (Kenya)  ...
# 65527                      Borana Ethnic Militia (Kenya)  ...
# 65528                      Borana Ethnic Militia (Kenya)  ...
# 65529                        OLF: Oromo Liberation Front  ...
# 65530                      Borana Ethnic Militia (Kenya)  ...
#
#                 ADMIN3         LOCATION LATITUDE  LONGITUDE  GEO_PRECISION  \
# 12854          Maianga           Luanda    -8838      13234              3
# 12898           Cayavi           Bhisho   -12854      13928              1
# 12909           Cuango          Cafunfo    -8,78      17,99              2
# 13020          Maianga           Luanda    -8838      13234              1
# 13027  Kuito Kuanavale  Cuito Cuanavale   -15167      19183              1
# ...                ...              ...      ...        ...            ...
# 65526         Township           Budada     1735      40,94              2
# 65527         Township           Gerari     1799      40158              2
# 65528         Township           Muduma     1579      40259              2
# 65529         Township             Tuli     1643      40343              1
# 65530         Township             Tuli     1643      40343              1
#
#                    SOURCE   SOURCE_SCALE  \
# 12854                IRIN  International
# 12898  Think Africa Press          Other
# 12909         Maka Angola       National
# 13020                 VOA  International
# 13027                 VOA  International
# ...                   ...            ...
# 65526          All Africa       Regional
# 65527          All Africa       Regional
# 65528          All Africa       Regional
# 65529             Reuters  International
# 65530          All Africa       Regional
#
#                                                    NOTES FATALITIES  \
# 12854  almost 18,000 people have been deported to the...          0
# 12898  A protest becomes violent, at least two people...          2
# 12909  More than 15,000 citizens took to the streets ...          0
# 13020  At least 20 people were injured when police an...          0
# 13027  MPLA supporters attacked and stoned the Unita ...          0
# ...                                                  ...        ...
# 65526  OLF and Borana ethnic militia attack civilians...         28
# 65527  OLF and Borana ethnic militia attack civilians...         28
# 65528  OLF and Borana ethnic militia attack civilians...         28
# 65529  Ethnic raiders and OLF attack Degodia Somali e...         28
# 65530  OLF and Borana ethnic militia attack civilians...         28
#
#         TIMESTAMP
# 12854  1571091923
# 12898  1552577509
# 12909  1559160528
# 13020  1552576897
# 13027  1552576893
# ...           ...
# 65526  1552577673
# 65527  1552577673
# 65528  1552577673
# 65529  1553544833
# 65530  1553544833
#
# [1627 rows x 29 columns]

# %%
df.describe()
# Out:
#                ISO  EVENT_ID_NO_CNTY         YEAR  TIME_PRECISION  \
# count  1627.000000       1627.000000  1627.000000     1627.000000
# mean    201.303012       8263.755378  2016.119852        1.129072
# std      90.378504      10483.372004     5.565424        0.389669
# min      24.000000          7.000000  1997.000000        1.000000
# 25%     140.000000       1648.500000  2015.000000        1.000000
# 50%     180.000000       3787.000000  2019.000000        1.000000
# 75%     231.000000      10529.000000  2020.000000        1.000000
# max     404.000000      47793.000000  2021.000000        3.000000
#
#             INTER1       INTER2  INTERACTION  GEO_PRECISION   FATALITIES  \
# count  1627.000000  1627.000000  1627.000000    1627.000000  1627.000000
# mean      3.770744     5.311002    38.714813       1.269207     3.460356
# std       1.498151     2.162898    16.539521       0.493555    19.679133
# min       1.000000     1.000000    11.000000       1.000000     0.000000
# 25%       3.000000     4.000000    23.000000       1.000000     0.000000
# 50%       4.000000     7.000000    37.000000       1.000000     0.000000
# 75%       5.000000     7.000000    55.000000       1.000000     2.000000
# max       8.000000     8.000000    78.000000       3.000000   600.000000
#
#           TIMESTAMP
# count  1.627000e+03
# mean   1.582706e+09
# std    1.475060e+07
# min    1.552576e+09
# 25%    1.571260e+09
# 50%    1.580773e+09
# 75%    1.594971e+09
# max    1.610411e+09

# %%
df.isnull().sum()
# Out:
# ISO                 0
# EVENT_ID_CNTY       0
# EVENT_ID_NO_CNTY    0
# EVENT_DATE          0
# YEAR                0
# TIME_PRECISION      0
# EVENT_TYPE          0
# SUB_EVENT_TYPE      0
# ACTOR1              0
# ASSOC_ACTOR_1       0
# INTER1              0
# ACTOR2              0
# ASSOC_ACTOR_2       0
# INTER2              0
# INTERACTION         0
# REGION              0
# COUNTRY             0
# ADMIN1              0
# ADMIN2              0
# ADMIN3              0
# LOCATION            0
# LATITUDE            0
# LONGITUDE           0
# GEO_PRECISION       0
# SOURCE              0
# SOURCE_SCALE        0
# NOTES               0
# FATALITIES          0
# TIMESTAMP           0
# dtype: int64

# %%
df.head(5)
# Out:
#        ISO EVENT_ID_CNTY  EVENT_ID_NO_CNTY       EVENT_DATE  YEAR  \
# 12854   24       ANG2923              2923  15-juillet-2009  2009
# 12898   24       ANG2969              2969  28-juillet-2012  2012
# 12909   24       ANG2983              2983     15-juin-2013  2013
# 13020   24       ANG3096              3096      03-mai-2017  2017
# 13027   24       ANG3105              3105      17-mai-2017  2017
#
#        TIME_PRECISION                  EVENT_TYPE  \
# 12854               3  Violence against civilians
# 12898               1                       Riots
# 12909               1                    Protests
# 13020               1                    Protests
# 13027               1                       Riots
#
#                            SUB_EVENT_TYPE                           ACTOR1  \
# 12854                     Sexual violence  Police Forces of Angola (1975-)
# 12898               Violent demonstration                 Rioters (Angola)
# 12909           Protest with intervention              Protesters (Angola)
# 13020  Excessive force against protesters              Protesters (Angola)
# 13027                        Mob violence                 Rioters (Angola)
#
#                                            ASSOC_ACTOR_1  ...  \
# 12854  Military Forces of Angola (1975-); Civilians (...  ...
# 12898  UNITA: National Union for the Total Independen...  ...
# 12909                                     Women (Angola)  ...
# 13020                                 Prisoners (Angola)  ...
# 13027  MPLA: Popular Movement for the Liberation of A...  ...
#
#                 ADMIN3         LOCATION LATITUDE  LONGITUDE  GEO_PRECISION  \
# 12854          Maianga           Luanda    -8838      13234              3
# 12898           Cayavi           Bhisho   -12854      13928              1
# 12909           Cuango          Cafunfo    -8,78      17,99              2
# 13020          Maianga           Luanda    -8838      13234              1
# 13027  Kuito Kuanavale  Cuito Cuanavale   -15167      19183              1
#
#                    SOURCE   SOURCE_SCALE  \
# 12854                IRIN  International
# 12898  Think Africa Press          Other
# 12909         Maka Angola       National
# 13020                 VOA  International
# 13027                 VOA  International
#
#                                                    NOTES FATALITIES  \
# 12854  almost 18,000 people have been deported to the...          0
# 12898  A protest becomes violent, at least two people...          2
# 12909  More than 15,000 citizens took to the streets ...          0
# 13020  At least 20 people were injured when police an...          0
# 13027  MPLA supporters attacked and stoned the Unita ...          0
#
#         TIMESTAMP
# 12854  1571091923
# 12898  1552577509
# 12909  1559160528
# 13020  1552576897
# 13027  1552576893
#
# [5 rows x 29 columns]

# %%
df['TIMESTAMP'] = pd.to_datetime(df["TIMESTAMP"])

# %%
df['TIMESTAMP']
# Out:
# 12854   1970-01-01 00:00:01.571091923
# 12898   1970-01-01 00:00:01.552577509
# 12909   1970-01-01 00:00:01.559160528
# 13020   1970-01-01 00:00:01.552576897
# 13027   1970-01-01 00:00:01.552576893
#                      ...
# 65526   1970-01-01 00:00:01.552577673
# 65527   1970-01-01 00:00:01.552577673
# 65528   1970-01-01 00:00:01.552577673
# 65529   1970-01-01 00:00:01.553544833
# 65530   1970-01-01 00:00:01.553544833
# Name: TIMESTAMP, Length: 1627, dtype: datetime64[ns]

# %%
df['REGION']
# Out:
# 12854     Middle Africa
# 12898     Middle Africa
# 12909     Middle Africa
# 13020     Middle Africa
# 13027     Middle Africa
#               ...
# 65526    Eastern Africa
# 65527    Eastern Africa
# 65528    Eastern Africa
# 65529    Eastern Africa
# 65530    Eastern Africa
# Name: REGION, Length: 1627, dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns
x = df['COUNTRY']
y = df['EVENT_TYPE']
plt.hist(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 4
#       2 x = df['COUNTRY']
#       3 y = df['EVENT_TYPE']
# ----> 4 plt.hist(x, y, bins=10)
#       5 plt.show()
#
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# TypeError: hist() got multiple values for argument 'bins'
